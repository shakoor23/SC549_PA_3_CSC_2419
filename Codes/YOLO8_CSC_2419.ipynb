# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.2 MB/s eta 0:00:00
# ...

# %%
# !yolo version
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# 8.4.14

# %%
# !ls /content/drive/MyDrive/SC549_CSC2419_PA_3/Dataset1
# !ls /content/drive/MyDrive/SC549_CSC2419_PA_3/Dataset1/images
# !ls /content/drive/MyDrive/SC549_CSC2419_PA_3/Dataset1/labels
# Out:
# images	labels	Weight_lifting.yaml
# train  val
# train  val

# %%
import os

yaml_path = "/content/drive/MyDrive/SC549_CSC2419_PA_3/Dataset1/Weight_lifting.yaml"
print("YAML exists:", os.path.exists(yaml_path))
# Out:
# YAML exists: True

# %%
from ultralytics import YOLO

# Load pretrained YOLOv8 model
model = YOLO("yolov8n.pt")

# %%
# Train on your dataset
model.train(
    data="/content/drive/MyDrive/SC549_CSC2419_PA_3/Dataset1/Weight_lifting.yaml",
    epochs=20,
    imgsz=640,
    batch=2,
    project="/content/drive/MyDrive/SC549_CSC2419_PA_3",
    name="WeightLifting_YOLO"
)
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...
